# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# # Patric Nondayi
#
# Data scientist

# %% [markdown]
# I am interested in data science because I am trying to navigate a new career path.
# Data science is becoming more valueable in terms of giving insite and driving businesses into profitable strategies thus I am interested on.

# %% [markdown]
# # adding numbers

# %%
2+2+7+15
# Out:
# 26
